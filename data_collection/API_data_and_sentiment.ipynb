# %% [markdown]
# # Retrieve API data and Perform Sentiment Analysis

# %%
# You will need to create an API key for News API and include it in config.py
from config import n_key
from getNewsAPIdata import getNewsAPIData
import pandas as pd

# %%
# Change these variables to your desired search and your initials 

# Our chosen keywords
keywords = ['refugee', 'refugees', 'migrant', 'migrants', 'immigrant', 'immigrants', 'immigration']

# Our chosen domains because we have related survey data on these domains from the Pew Research Center
domains = ['washingtonpost.com', 
'politico.com', 
'buzzfeed.com', 
'wsj.com', 
'usatoday.com', 
'nbcnews.com', 
'msnbc.com', 
'foxnews.com', 
'cbsnews.com', 
'breitbart.com', 
'bloomberg.com', 
'aljazeera.com', 
'cnn.com']


initials = 'RCK_test'

# %%
# Retrieve API data and export to CSV file
getNewsAPIData(n_key, keywords, domains, initials)

# %%
# Read in csv file that contains API data - file name is 'sentimentNewsAPIdata{initials}.csv'
df = pd.read_csv('sentimentNewsAPIdataRCK_test.csv')
df
# Out:
#           Keyword               Source  \
# 0         refugee  The Washington Post
# 1         refugee  The Washington Post
# 2         refugee  The Washington Post
# 3         refugee  The Washington Post
# 4         refugee  The Washington Post
# ...           ...                  ...
# 2230  immigration                  CNN
# 2231  immigration                  CNN
# 2232  immigration                  CNN
# 2233  immigration                  CNN
# 2234  immigration                  CNN
#
#                                       Author  \
# 0                                Nick Miroff
# 1                           Gillian Brockell
# 2            Rebecca Sanders, Jack Mewhirter
# 3                               Greg Sargent
# 4                              James Hohmann
# ...                                      ...
# 2230  Brianna Keilar and Caroline Kelly, CNN
# 2231                      By Jennifer Yellin
# 2232                           Taylor Romine
# ...
