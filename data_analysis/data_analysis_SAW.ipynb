# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Increase the quality and resolution of our charts so we can copy/paste or just
# directly save from here.
# See:
# https://ipython.org/ipython-doc/3/api/generated/IPython.display.html
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina', quality=100)

# You can also just do this in Colab/Jupyter, some "magic":
# %config InlineBackend.figure_format='retina'

# %%
df = pd.read_csv('../data_cleaning/cleaned_dataset.csv')
df.head()
# Out:
#      Keyword               Source                                 Author  \
# 0  immigrant  The Washington Post                            Nick Miroff
# 1  immigrant  The Washington Post            Nick Miroff, Devlin Barrett
# 2  immigrant  The Washington Post                            Tim Elfrink
# 3  immigrant  The Washington Post  James A. McCann, Michael Jones-Correa
# 4  immigrant  The Washington Post                           Steven Moore
#
#                                                Title  \
# 0  Hospital where activists say ICE detainees wer...
# 1  ICE preparing targeted arrests in ‘sanctuary c...
# 2  ‘They’re still not taking this seriously’: Whi...
# 3  Trump’s attacks prompted Latino immigrants to ...
# 4  ICE is accused of sterilizing detainees. That ...
#
#                                                  URL  \
# 0  https://www.washingtonpost.com/immigration/ice...
# 1  https://www.washingtonpost.com/immigration/tru...
# ...

# %%
plt.style.available
plt.style.use('fivethirtyeight')

# %%
pie = df['Source'].value_counts().plot.pie(autopct='%.2f%%', fontsize=12, figsize=(12, 12), labeldistance=None, legend=True, shadow=True)
pie
df['Source'].value_counts()
# Out:
# Breitbart News             261
# The Washington Post        174
# Fox News                   169
# Al Jazeera English         162
# NBC News                   124
# Politico                   109
# CBS News                    68
# The Wall Street Journal      7
# Buzzfeed                     1
# MSNBC                        1
# Name: Source, dtype: int64

# %%
df['Source'].value_counts().plot.bar()

# %%
buzz = df.loc[df['Source']=='Buzzfeed', 'Title'].item()
print(buzz)

msnbc = df.loc[df['Source']=='MSNBC', 'Title'].item()
print(msnbc)
# Out:
# Which American Quirk Do Your Immigrant Parents Always Talk About?
# Homeland Security whistleblower: Team Trump distorted intelligence

# %%
df.groupby('Source').mean().plot.barh(figsize=(10, 8))
plt.tight_layout()
scores = df.groupby('Source').mean()

# %%
scores['compound score'].plot.barh()

# %%
scores['positive score'].plot.barh(color='y')

# %%
scores['negative score'].plot.barh(color='r')

# %%
scores['neutral score'].plot.barh(color='green')

# %%
scores
# Out:
#                          compound score  negative score  positive score  \
# Source
# Al Jazeera English            -0.211046        0.183840        0.052895
# Breitbart News                -0.177283        0.162885        0.066326
# Buzzfeed                       0.000000        0.000000        0.000000
# CBS News                      -0.053441        0.101926        0.065235
# Fox News                      -0.094572        0.131864        0.081645
# MSNBC                          0.421500        0.221000        0.451000
# NBC News                      -0.083010        0.119798        0.072605
# Politico                      -0.047876        0.092202        0.077358
# The Wall Street Journal       -0.113743        0.143286        0.100000
# The Washington Post           -0.071519        0.122724        0.080236
#
#                          neutral score
# Source
# Al Jazeera English            0.763284
# Breitbart News                0.770789
# ...

# %%
df['compound score'].mean()
# Out:
# -0.11933810408921926

# %%
scores['compound score'].plot.box()

# %%
df.boxplot(column='compound score', by='Source', figsize=(10, 10), vert=False) 
plt.xticks(rotation='vertical')
# Out:
# (array([-1.25, -1.  , -0.75, -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,
#          1.  ]),
#  <a list of 10 Text major ticklabel objects>)

# %%
df['Title'].count()
# df.plot.scatter(df['Title'].count(), 'compound score')
# Out:
# 1076

# %%
df['Author'].value_counts().head().plot.bar(linewidth=1)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
df.loc[df['Author']=='Chris Tomlinson']
# Out:
#          Keyword          Source           Author  \
# 442   immigrants  Breitbart News  Chris Tomlinson
# 444   immigrants  Breitbart News  Chris Tomlinson
# 445   immigrants  Breitbart News  Chris Tomlinson
# 793      migrant  Breitbart News  Chris Tomlinson
# 797      migrant  Breitbart News  Chris Tomlinson
# 798      migrant  Breitbart News  Chris Tomlinson
# 799      migrant  Breitbart News  Chris Tomlinson
# 800      migrant  Breitbart News  Chris Tomlinson
# 801      migrant  Breitbart News  Chris Tomlinson
# 804      migrant  Breitbart News  Chris Tomlinson
# 806      migrant  Breitbart News  Chris Tomlinson
# 808      migrant  Breitbart News  Chris Tomlinson
# 809      migrant  Breitbart News  Chris Tomlinson
# 810      migrant  Breitbart News  Chris Tomlinson
# 811      migrant  Breitbart News  Chris Tomlinson
# 813      migrant  Breitbart News  Chris Tomlinson
# 815      migrant  Breitbart News  Chris Tomlinson
# 818      migrant  Breitbart News  Chris Tomlinson
# ...

# %%
df.loc[df['Author']=='Neil Munro']
# Out:
#          Keyword          Source      Author  \
# 156    immigrant  Breitbart News  Neil Munro
# 158    immigrant  Breitbart News  Neil Munro
# 159    immigrant  Breitbart News  Neil Munro
# 160    immigrant  Breitbart News  Neil Munro
# 163    immigrant  Breitbart News  Neil Munro
# 170    immigrant  Breitbart News  Neil Munro
# 179    immigrant  Breitbart News  Neil Munro
# 180    immigrant  Breitbart News  Neil Munro
# 185    immigrant  Breitbart News  Neil Munro
# 186    immigrant  Breitbart News  Neil Munro
# 187    immigrant  Breitbart News  Neil Munro
# 430   immigrants  Breitbart News  Neil Munro
# 431   immigrants  Breitbart News  Neil Munro
# 433   immigrants  Breitbart News  Neil Munro
# 436   immigrants  Breitbart News  Neil Munro
# 437   immigrants  Breitbart News  Neil Munro
# 439   immigrants  Breitbart News  Neil Munro
# 440   immigrants  Breitbart News  Neil Munro
# 453   immigrants  Breitbart News  Neil Munro
# 454   immigrants  Breitbart News  Neil Munro
# ...

# %%
df.loc[df['Author']=='John Binder']
# Out:
#          Keyword          Source       Author  \
# 153    immigrant  Breitbart News  John Binder
# 155    immigrant  Breitbart News  John Binder
# 162    immigrant  Breitbart News  John Binder
# 165    immigrant  Breitbart News  John Binder
# 167    immigrant  Breitbart News  John Binder
# 172    immigrant  Breitbart News  John Binder
# 174    immigrant  Breitbart News  John Binder
# 176    immigrant  Breitbart News  John Binder
# 178    immigrant  Breitbart News  John Binder
# 183    immigrant  Breitbart News  John Binder
# 432   immigrants  Breitbart News  John Binder
# 438   immigrants  Breitbart News  John Binder
# 678  immigration  Breitbart News  John Binder
# 680  immigration  Breitbart News  John Binder
# 681  immigration  Breitbart News  John Binder
# 682  immigration  Breitbart News  John Binder
# 683  immigration  Breitbart News  John Binder
# 684  immigration  Breitbart News  John Binder
# 685  immigration  Breitbart News  John Binder
# ...

# %%
plt.style.use('fivethirtyeight')
df['Source'].value_counts().plot.bar()
# plt.tight_layout()
# plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
